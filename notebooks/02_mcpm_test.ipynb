# %%
import sys\nsys.path.append('../')\nimport matplotlib.pyplot as plt\nfrom src.solvers.mcpm_solver import MCPMSolver

# %%
# Initialize the solver\nsolver = MCPMSolver(grid_size=(200, 200), num_agents=2000, sensing_distance=3)

# %%
# Run the simulation\nsolver.run_simulation(num_iterations=100)

# %%
# Visualize the trace field\nplt.figure(figsize=(10, 10))\nplt.imshow(solver.trace_field, cmap='hot')\nplt.title('Trace Field after 100 iterations')\nplt.show()
