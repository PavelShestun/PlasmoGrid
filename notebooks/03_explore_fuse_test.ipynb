# %%
import sys\nsys.path.append('../')\nimport matplotlib.pyplot as plt\nfrom src.solvers.explore_fuse_solver import ExploreFuseSolver

# %%
# Define terminals\nterminals = [(10, 10), (80, 80), (10, 80), (80, 10)]

# %%
# Initialize the solver\nsolver = ExploreFuseSolver(grid_size=(100, 100), terminals=terminals)

# %%
# Run the simulation\nsolver.run_simulation(num_iterations=50)

# %%
# Visualize the final grid state\nplt.figure(figsize=(10, 10))\nplt.imshow(solver.grid, cmap='viridis')\nplt.title('Grid State after 50 iterations')\nplt.show()
