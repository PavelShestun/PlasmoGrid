# %%
import sys\nsys.path.append('../')\nfrom src.graph import PhysarumGraph\nfrom src.solvers.discrete_solver import DiscreteSolver\nfrom src.visualization.visualizer import visualize_graph

# %%
# Create a simple Wheatstone bridge graph\nedges = [(0, 1), (0, 2), (1, 3), (2, 3), (1, 2)]\ngraph = PhysarumGraph()\ngraph.add_edges_from(edges)

# %%
# Visualize the initial state\nvisualize_graph(graph, title='Initial State')

# %%
# Set up the solver and run the simulation\nsource_node = 0\nsink_node = 3\nsolver = DiscreteSolver(graph, source_node, sink_node)\nsolver.run_simulation(num_iterations=10)

# %%
# Visualize the final state\nvisualize_graph(graph, title='Final State after 10 iterations')
