# %%
import sys\nsys.path.append('../src/')\nfrom graph import PhysarumGraph\nfrom solvers.discrete_solver import DiscreteSolver\nfrom visualization.visualizer import plot_interactive_convergence

# %%
# Create a simple graph\nedges = [(0, 1), (0, 2), (1, 3), (2, 3), (1, 4), (4, 2)]\ngraph = PhysarumGraph(edges)\n\n# Set up and run the solver\nsolver = DiscreteSolver(graph, source_node=0, sink_node=3)\nsolver.run_simulation_with_t_point(max_iterations=50)

# %%
# Generate and display the interactive plot\nplot_interactive_convergence(solver.d_path_lengths)
