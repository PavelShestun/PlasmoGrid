# %%
import sys\nsys.path.append('../')\nfrom src.graph import PhysarumGraph\nfrom src.solvers.discrete_solver import DiscreteSolver\nfrom src.visualization.visualizer import animate_discrete_solver

# %%
# Create a simple graph\nedges = [(0, 1), (0, 2), (1, 3), (2, 3), (1, 2)]\ngraph = PhysarumGraph(edges)\n\n# Set up the solver\nsolver = DiscreteSolver(graph, source_node=0, sink_node=3)

# %%
# Generate and display the animation\nanimation = animate_discrete_solver(solver, num_frames=15)\nanimation
