# %%
import sys\nsys.path.append('../')\nfrom src.benchmarking.data_loader import download_string_db_data\nfrom src.visualization.visualizer import visualize_graph

# %%
# Download E. coli data (smaller than human) with a high confidence score\ngraph = download_string_db_data(organism_id='511145', score_threshold=700)

# %%
# Visualize a small subgraph for clarity\nimport networkx as nx\nnodes_to_show = list(graph.nodes())[:50] # Get the first 50 nodes\nsubgraph = graph.subgraph(nodes_to_show)\nvisualize_graph(subgraph, title='Subgraph of E. coli Protein Interaction Network')
